# %% [markdown]
# ## 1. Import Data

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ## 2. Read Datasets using Pandas

# %%
data = pd.read_csv("train_ver2.csv")
# Out:
# /Library/Python/2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (5,8,11,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## 3. Sort By ncodepers (Customer Code)

# %%
sorted_data = data.sort(['ncodpers','fecha_dato'],ascending=[True,True])
sorted_data
# Out:
# /Library/Python/2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#           fecha_dato  ncodpers ind_empleado pais_residencia sexo  age  \
# 416965    2015-01-28     15889            F              ES    V   56
# 836224    2015-02-28     15889            F              ES    V   56
# 1673961   2015-03-28     15889            F              ES    V   56
# 1882060   2015-04-28     15889            F              ES    V   56
# 3144382   2015-05-28     15889            F              ES    V   56
# 3565837   2015-06-28     15889            F              ES    V   56
# 4078996   2015-07-28     15889            F              ES    V   56
# 5319234   2015-08-28     15889            F              ES    V   56
# 5705188   2015-09-28     15889            F              ES    V   56
# 6973298   2015-10-28     15889            F              ES    V   56
# ...

# %%
filtered_sorted_data = sorted_data.head(10000)

# %%
filtered_sorted_data.to_csv("filtered_data_mining.csv", index=False)

# %% [markdown]
# ## Statistics

# %%
filtered_sorted_data.describe()
# Out:
#            ncodpers    ind_nuevo       indrel  tipodom     cod_prov  \
# count  10000.000000  9988.000000  9988.000000   9988.0  9954.000000
# mean   16425.027000     0.002503     1.127553      1.0    27.340968
# std      358.059633     0.049970     3.533437      0.0     5.586138
# min    15889.000000     0.000000     1.000000      1.0     1.000000
# 25%    16093.000000     0.000000     1.000000      1.0    28.000000
# 50%    16426.000000     0.000000     1.000000      1.0    28.000000
# 75%    16739.000000     0.000000     1.000000      1.0    28.000000
# max    17044.000000     1.000000    99.000000      1.0    49.000000
#
#        ind_actividad_cliente         renta  ind_ahor_fin_ult1  \
# count            9988.000000  9.017000e+03       10000.000000
# mean                0.700541  2.325542e+05           0.001700
# std                 0.458044  1.837271e+05           0.041198
# min                 0.000000  3.166824e+04           0.000000
# ...

# %%
str = "Date	Customer_Code	Employee_index	Country_residence	sex	age	Date_Registered	New_customer_Index	seniority	Primary	Last_date_primary	type	relation_type	Residence_index	Foreigner_index	Spouse_index	channel_join	Deceased_index	Primary_Addr	Province_code	Province_name	Activity_index	Gross_income	Segmentation	Saving_Account	Guarantees	Current_Accounts	Derivada_Account	Payroll_Account	Junior_Account	Mas_particular_Account	particular_Account	Plus_Account	Shortterm_deposits	Mediumterm_deposits	Longterm_deposits	eaccount	Funds	Mortgage	Pensions	Loans	Taxes	Credit_Card	Securities	Home_Account	Payroll	Pensions	Direct_Debit"
columns = str.split("\t");
columns
pd2 = pd.DataFrame(data, columns=columns)
